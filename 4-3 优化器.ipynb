# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
###载入数据集
mnist= input_data.read_data_sets('MNIST_data',one_hot=True)
###计算有多少批次
batch_size=100
n_batch = mnist.train.num_examples // batch_size

###定义连个placeholder
x= tf.placeholder(tf.float32,[None,784])
y= tf.placeholder(tf.float32,[None,10])
##再定义一个placehold
keep_prob=tf.placeholder(tf.float32)
###创建一个简单的神经网络

W1= tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1=tf.Variable(tf.zeros([2000])+0.1)
L1=tf.nn.tanh(tf.matmul(x,W1)+b1)
###自定义的神经元drop out
L1_drop=tf.nn.dropout(L1,keep_prob)



W2= tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b2=tf.Variable(tf.zeros([2000])+0.1)
L2=tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
###自定义的神经元drop out
L2_drop=tf.nn.dropout(L2,keep_prob)




W3= tf.Variable(tf.truncated_normal([2000,1000],stddev=0.1))
b3=tf.Variable(tf.zeros([1000])+0.1)
L3=tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
###自定义的神经元drop out
L3_drop=tf.nn.dropout(L3,keep_prob)




W4= tf.Variable(tf.truncated_normal([1000,10],stddev=0.1))
b4=tf.Variable(tf.zeros([10])+0.1)
prediction= tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)


###二次代价函数
# loss= tf.reduce_mean(tf.square(y- prediction))
loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
###使用梯度下降法

####
train= tf.train.GradientDescentOptimizer(0.02).minimize(loss)










###初始化变量
init= tf.global_variables_initializer()


###结果存在在一个布尔型的变量中
###tf.argmax是用来判断其中的最大值
correct_prediciton = tf.equal(tf.arg_max(y,1),tf.arg_max(prediction,1))
###求准确率
###tf.cast是用来转化的
accuracy = tf.reduce_mean(tf.cast(correct_prediciton,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(320):
        for batch in range(n_batch):
            ###首先获得一个批次，大小为100
            batch_xs,batch_ys= mnist.train.next_batch(batch_size)
            sess.run(train,feed_dict={x:batch_xs,y:batch_ys,keep_prob:1})
            
        test_acc=sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        train_acc=sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})

        print('Iter'+str(epoch)+',Testing Accuracy'+str(test_acc)+',Training Accuracy'+str(train_acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuracy0.9035,Training Accuracy0.90256363
# Iter1,Testing Accuracy0.9234,Training Accuracy0.9322
# Iter2,Testing Accuracy0.9328,Training Accuracy0.9454727
# Iter3,Testing Accuracy0.9376,Training Accuracy0.95347273
# Iter4,Testing Accuracy0.9415,Training Accuracy0.9590909
# Iter5,Testing Accuracy0.9446,Training Accuracy0.9628364
# Iter6,Testing Accuracy0.9474,Training Accuracy0.966
# Iter7,Testing Accuracy0.9493,Training Accuracy0.96843636
# Iter8,Testing Accuracy0.9504,Training Accuracy0.97065455
# Iter9,Testing Accuracy0.9516,Training Accuracy0.9725818
# Iter10,Testing Accuracy0.9534,Training Accuracy0.9743818
# Iter11,Testing Accuracy0.9535,Training Accuracy0.97603637
# Iter12,Testing Accuracy0.9534,Training Accuracy0.97696364
# Iter13,Testing Accuracy0.9547,Training Accuracy0.9782364
# Iter14,Testing Accuracy0.9552,Training Accuracy0.97907275
# Iter15,Testing Accuracy0.9558,Training Accuracy0.97981817
# Iter16,Testing Accuracy0.9562,Training Accuracy0.9804
# Iter17,Testing Accuracy0.957,Training Accuracy0.9810182
# Iter18,Testing Accuracy0.957,Training Accuracy0.9815636
# Iter19,Testing Accuracy0.9576,Training Accuracy0.9822364
# Iter20,Testing Accuracy0.9587,Training Accuracy0.98285455
# Iter21,Testing Accuracy0.9587,Training Accuracy0.98341817
# Iter22,Testing Accuracy0.9594,Training Accuracy0.9838
# Iter23,Testing Accuracy0.9596,Training Accuracy0.9842
# Iter24,Testing Accuracy0.9599,Training Accuracy0.9847818
# Iter25,Testing Accuracy0.9605,Training Accuracy0.98514545
# Iter26,Testing Accuracy0.9612,Training Accuracy0.9854909
# Iter27,Testing Accuracy0.9614,Training Accuracy0.9857091
# Iter28,Testing Accuracy0.9619,Training Accuracy0.98614544
# Iter29,Testing Accuracy0.9619,Training Accuracy0.98643637
# Iter30,Testing Accuracy0.9625,Training Accuracy0.9867091
# Iter31,Testing Accuracy0.9629,Training Accuracy0.9869636
# Iter32,Testing Accuracy0.9628,Training Accuracy0.9872
# Iter33,Testing Accuracy0.9631,Training Accuracy0.9873818
# Iter34,Testing Accuracy0.9635,Training Accuracy0.9876364
# Iter35,Testing Accuracy0.9633,Training Accuracy0.9878182
# Iter36,Testing Accuracy0.9635,Training Accuracy0.98794544
# Iter37,Testing Accuracy0.964,Training Accuracy0.9881273
# Iter38,Testing Accuracy0.9635,Training Accuracy0.98825455
# Iter39,Testing Accuracy0.9639,Training Accuracy0.98843634
# Iter40,Testing Accuracy0.9639,Training Accuracy0.9885273
# Iter41,Testing Accuracy0.9639,Training Accuracy0.98867273
# Iter42,Testing Accuracy0.9636,Training Accuracy0.9888909
# Iter43,Testing Accuracy0.9638,Training Accuracy0.98907274
# Iter44,Testing Accuracy0.9638,Training Accuracy0.9891818
# Iter45,Testing Accuracy0.964,Training Accuracy0.9893091
# Iter46,Testing Accuracy0.9637,Training Accuracy0.9893636
# Iter47,Testing Accuracy0.9645,Training Accuracy0.98947275
# Iter48,Testing Accuracy0.9645,Training Accuracy0.9896182
# Iter49,Testing Accuracy0.9642,Training Accuracy0.98972726
# Iter50,Testing Accuracy0.9643,Training Accuracy0.9899091
# Iter51,Testing Accuracy0.9644,Training Accuracy0.9900182
# Iter52,Testing Accuracy0.9643,Training Accuracy0.9901091
# Iter53,Testing Accuracy0.9648,Training Accuracy0.9902545
# Iter54,Testing Accuracy0.9651,Training Accuracy0.9904182
# Iter55,Testing Accuracy0.965,Training Accuracy0.99054545
# Iter56,Testing Accuracy0.9651,Training Accuracy0.99063635
# Iter57,Testing Accuracy0.9649,Training Accuracy0.9906909
# Iter58,Testing Accuracy0.9661,Training Accuracy0.99078184
# Iter59,Testing Accuracy0.9662,Training Accuracy0.9909091
# Iter60,Testing Accuracy0.9662,Training Accuracy0.99103636
# Iter61,Testing Accuracy0.9663,Training Accuracy0.99112725
# Iter62,Testing Accuracy0.9662,Training Accuracy0.9911818
# Iter63,Testing Accuracy0.9665,Training Accuracy0.99127275
# Iter64,Testing Accuracy0.9667,Training Accuracy0.99134547
# Iter65,Testing Accuracy0.966,Training Accuracy0.9914182
# Iter66,Testing Accuracy0.967,Training Accuracy0.9915091
# Iter67,Testing Accuracy0.9671,Training Accuracy0.9915636
# Iter68,Testing Accuracy0.9668,Training Accuracy0.9916
# Iter69,Testing Accuracy0.9673,Training Accuracy0.99167275
# Iter70,Testing Accuracy0.967,Training Accuracy0.9917091
# Iter71,Testing Accuracy0.9671,Training Accuracy0.99178183
# Iter72,Testing Accuracy0.9674,Training Accuracy0.9918727
# Iter73,Testing Accuracy0.9675,Training Accuracy0.992
# Iter74,Testing Accuracy0.9676,Training Accuracy0.9920909
# Iter75,Testing Accuracy0.9675,Training Accuracy0.9922182
# Iter76,Testing Accuracy0.9677,Training Accuracy0.99225456
# Iter77,Testing Accuracy0.9674,Training Accuracy0.99236363
# Iter78,Testing Accuracy0.9675,Training Accuracy0.99241817
# Iter79,Testing Accuracy0.9673,Training Accuracy0.9924545
# Iter80,Testing Accuracy0.9674,Training Accuracy0.99256366
# Iter81,Testing Accuracy0.9677,Training Accuracy0.99258184
# Iter82,Testing Accuracy0.9676,Training Accuracy0.9926364
# Iter83,Testing Accuracy0.9672,Training Accuracy0.9927091
# Iter84,Testing Accuracy0.9672,Training Accuracy0.99274546
# Iter85,Testing Accuracy0.9675,Training Accuracy0.99283636
# Iter86,Testing Accuracy0.9674,Training Accuracy0.9929091
# Iter87,Testing Accuracy0.9671,Training Accuracy0.993
# Iter88,Testing Accuracy0.9679,Training Accuracy0.9930182
# Iter89,Testing Accuracy0.9679,Training Accuracy0.99305457
# Iter90,Testing Accuracy0.9677,Training Accuracy0.99307275
# Iter91,Testing Accuracy0.9675,Training Accuracy0.99314547
# Iter92,Testing Accuracy0.9679,Training Accuracy0.99316365
# Iter93,Testing Accuracy0.9679,Training Accuracy0.99325454
# Iter94,Testing Accuracy0.9683,Training Accuracy0.9932727
# Iter95,Testing Accuracy0.9683,Training Accuracy0.9932909
# Iter96,Testing Accuracy0.9684,Training Accuracy0.99334544
# Iter97,Testing Accuracy0.9685,Training Accuracy0.9933636
# Iter98,Testing Accuracy0.9685,Training Accuracy0.9933636
# Iter99,Testing Accuracy0.9685,Training Accuracy0.9933818
# Iter100,Testing Accuracy0.9688,Training Accuracy0.9934
# Iter101,Testing Accuracy0.9684,Training Accuracy0.99343634
# Iter102,Testing Accuracy0.9684,Training Accuracy0.99343634
# Iter103,Testing Accuracy0.9684,Training Accuracy0.99343634
# Iter104,Testing Accuracy0.9687,Training Accuracy0.99343634
# Iter105,Testing Accuracy0.9687,Training Accuracy0.9934545
# Iter106,Testing Accuracy0.9688,Training Accuracy0.99347275
# Iter107,Testing Accuracy0.9691,Training Accuracy0.9935455
# Iter108,Testing Accuracy0.9689,Training Accuracy0.99358183
# Iter109,Testing Accuracy0.9688,Training Accuracy0.99365455
# Iter110,Testing Accuracy0.9689,Training Accuracy0.99365455
# Iter111,Testing Accuracy0.9688,Training Accuracy0.9937091
# Iter112,Testing Accuracy0.9689,Training Accuracy0.99374545
# Iter113,Testing Accuracy0.9691,Training Accuracy0.9937636
# Iter114,Testing Accuracy0.9691,Training Accuracy0.9937636
# Iter115,Testing Accuracy0.9695,Training Accuracy0.9938
# Iter116,Testing Accuracy0.9694,Training Accuracy0.99381816
# Iter117,Testing Accuracy0.9698,Training Accuracy0.99381816
# Iter118,Testing Accuracy0.9697,Training Accuracy0.9938545
# Iter119,Testing Accuracy0.9696,Training Accuracy0.9938909
# Iter120,Testing Accuracy0.9696,Training Accuracy0.9939273
# Iter121,Testing Accuracy0.9699,Training Accuracy0.9939455
# Iter122,Testing Accuracy0.9697,Training Accuracy0.9939455
# Iter123,Testing Accuracy0.9698,Training Accuracy0.9940182
# Iter124,Testing Accuracy0.9699,Training Accuracy0.9940182
# Iter125,Testing Accuracy0.9698,Training Accuracy0.9940364
# Iter126,Testing Accuracy0.9699,Training Accuracy0.99407274
# Iter127,Testing Accuracy0.9701,Training Accuracy0.9940909
# Iter128,Testing Accuracy0.9702,Training Accuracy0.9941091
# Iter129,Testing Accuracy0.9704,Training Accuracy0.99414545
# Iter130,Testing Accuracy0.97,Training Accuracy0.9941818
# Iter131,Testing Accuracy0.97,Training Accuracy0.9941818
# Iter132,Testing Accuracy0.9699,Training Accuracy0.9941818
# Iter133,Testing Accuracy0.97,Training Accuracy0.9942
# Iter134,Testing Accuracy0.9699,Training Accuracy0.9942182
# Iter135,Testing Accuracy0.9702,Training Accuracy0.99423635
# Iter136,Testing Accuracy0.9702,Training Accuracy0.9942909
# Iter137,Testing Accuracy0.97,Training Accuracy0.99432725
# Iter138,Testing Accuracy0.9698,Training Accuracy0.9943454
# Iter139,Testing Accuracy0.9699,Training Accuracy0.9943454
# Iter140,Testing Accuracy0.97,Training Accuracy0.99438184
# Iter141,Testing Accuracy0.9699,Training Accuracy0.99438184
# Iter142,Testing Accuracy0.9703,Training Accuracy0.9944
# Iter143,Testing Accuracy0.9703,Training Accuracy0.9944182
# Iter144,Testing Accuracy0.9701,Training Accuracy0.9944364
# Iter145,Testing Accuracy0.9699,Training Accuracy0.99445456
# Iter146,Testing Accuracy0.97,Training Accuracy0.99447274
# Iter147,Testing Accuracy0.9699,Training Accuracy0.9944909
# Iter148,Testing Accuracy0.9698,Training Accuracy0.9944909
# Iter149,Testing Accuracy0.97,Training Accuracy0.9945091
# Iter150,Testing Accuracy0.9703,Training Accuracy0.99454546
# Iter151,Testing Accuracy0.9703,Training Accuracy0.9945818
# Iter152,Testing Accuracy0.9703,Training Accuracy0.9945818
# Iter153,Testing Accuracy0.97,Training Accuracy0.9945818
# Iter154,Testing Accuracy0.9702,Training Accuracy0.9945818
# Iter155,Testing Accuracy0.9703,Training Accuracy0.9946182
# Iter156,Testing Accuracy0.9705,Training Accuracy0.9946182
# Iter157,Testing Accuracy0.9706,Training Accuracy0.99465454
# Iter158,Testing Accuracy0.9706,Training Accuracy0.99465454
# Iter159,Testing Accuracy0.9707,Training Accuracy0.9946727
# Iter160,Testing Accuracy0.9707,Training Accuracy0.9946727
# Iter161,Testing Accuracy0.9707,Training Accuracy0.9946727
# Iter162,Testing Accuracy0.9705,Training Accuracy0.9946909
# Iter163,Testing Accuracy0.9707,Training Accuracy0.9947091
# Iter164,Testing Accuracy0.9706,Training Accuracy0.9947091
# Iter165,Testing Accuracy0.9708,Training Accuracy0.9947091
# Iter166,Testing Accuracy0.9708,Training Accuracy0.9947091
# Iter167,Testing Accuracy0.9709,Training Accuracy0.9947091
# Iter168,Testing Accuracy0.9708,Training Accuracy0.9947091
# Iter169,Testing Accuracy0.9708,Training Accuracy0.99474543
# Iter170,Testing Accuracy0.9707,Training Accuracy0.9947636
# Iter171,Testing Accuracy0.9705,Training Accuracy0.9947636
# Iter172,Testing Accuracy0.9706,Training Accuracy0.9948
# Iter173,Testing Accuracy0.9705,Training Accuracy0.9948182
# Iter174,Testing Accuracy0.9704,Training Accuracy0.9948182
# Iter175,Testing Accuracy0.9707,Training Accuracy0.9948364
# Iter176,Testing Accuracy0.9706,Training Accuracy0.9948364
# Iter177,Testing Accuracy0.9704,Training Accuracy0.9948364
# Iter178,Testing Accuracy0.9703,Training Accuracy0.99485457
# Iter179,Testing Accuracy0.9702,Training Accuracy0.99485457
# Iter180,Testing Accuracy0.9702,Training Accuracy0.99485457
# Iter181,Testing Accuracy0.9703,Training Accuracy0.9948909
# Iter182,Testing Accuracy0.9704,Training Accuracy0.9949091
# Iter183,Testing Accuracy0.9702,Training Accuracy0.99494547
# Iter184,Testing Accuracy0.9706,Training Accuracy0.99496365
# Iter185,Testing Accuracy0.9704,Training Accuracy0.995
# Iter186,Testing Accuracy0.9705,Training Accuracy0.995
# Iter187,Testing Accuracy0.9707,Training Accuracy0.9950182
# Iter188,Testing Accuracy0.9705,Training Accuracy0.9950182
# Iter189,Testing Accuracy0.9704,Training Accuracy0.99503636
# Iter190,Testing Accuracy0.9703,Training Accuracy0.99503636
# Iter191,Testing Accuracy0.9705,Training Accuracy0.99503636
# Iter192,Testing Accuracy0.9707,Training Accuracy0.99503636
# Iter193,Testing Accuracy0.9708,Training Accuracy0.99503636
# Iter194,Testing Accuracy0.9707,Training Accuracy0.9950727
# Iter195,Testing Accuracy0.9709,Training Accuracy0.9950727
# Iter196,Testing Accuracy0.9704,Training Accuracy0.9950727
# Iter197,Testing Accuracy0.9707,Training Accuracy0.9950727
# Iter198,Testing Accuracy0.971,Training Accuracy0.9950727
# Iter199,Testing Accuracy0.9709,Training Accuracy0.9950727
# Iter200,Testing Accuracy0.9709,Training Accuracy0.9950727
# Iter201,Testing Accuracy0.9711,Training Accuracy0.9950727
# Iter202,Testing Accuracy0.971,Training Accuracy0.9950727
# Iter203,Testing Accuracy0.971,Training Accuracy0.9950727
# Iter204,Testing Accuracy0.9708,Training Accuracy0.9950909
# Iter205,Testing Accuracy0.971,Training Accuracy0.9950909
# Iter206,Testing Accuracy0.9708,Training Accuracy0.9951091
# Iter207,Testing Accuracy0.9708,Training Accuracy0.9951091
# Iter208,Testing Accuracy0.971,Training Accuracy0.9951091
# Iter209,Testing Accuracy0.9707,Training Accuracy0.9951091
# Iter210,Testing Accuracy0.9708,Training Accuracy0.9951091
# Iter211,Testing Accuracy0.971,Training Accuracy0.9951091
# Iter212,Testing Accuracy0.9711,Training Accuracy0.99514544
# Iter213,Testing Accuracy0.9711,Training Accuracy0.9951818
# Iter214,Testing Accuracy0.9712,Training Accuracy0.9952
# Iter215,Testing Accuracy0.9713,Training Accuracy0.9952
# Iter216,Testing Accuracy0.9713,Training Accuracy0.9952
